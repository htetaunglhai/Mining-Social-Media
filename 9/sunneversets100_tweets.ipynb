# %%
import pandas as pd

# %%
bot_tweets = pd.read_csv(r"..\data\sunneversets100_tweets.csv")
bot_tweets.head()
# Out:
#                    id           created_at  favorites  retweets  retweeted  \
# 0  858919901842604033  2017-05-01 05:43:57          0         5      False
# 1  858158868853125125  2017-04-29 03:19:52          0        38      False
# 2  858158855364259840  2017-04-29 03:19:49          0        68      False
# 3  858158855355858944  2017-04-29 03:19:49          0       101      False
# 4  858158841250418688  2017-04-29 03:19:46          0        49      False
#
#                 source                                               text
# 0  Twitter for Android  RT @saxobank: Squawk: France election update: ...
# 1  Twitter for Android  RT @XHNews: #BeltandRoadInitiative facilitates...
# 2  Twitter for Android  RT @XHNews: White House says U.S. President @r...
# 3  Twitter for Android  RT @XHNews: Indonesia lifts #tsunami warning a...
# 4  Twitter for Android  RT @XHNews: Once "world's heaviest woman" flow...

# %%
bot_tweets.tail()
# Out:
#                       id           created_at  favorites  retweets  retweeted  \
# 2963  852453668574162944  2017-04-13 09:29:27          0         1      False
# 2964  852453630993195008  2017-04-13 09:29:18          0         1      False
# 2965  852453450822680576  2017-04-13 09:28:35          0         2      False
# 2966  852453362431905792  2017-04-13 09:28:14          0         6      False
# 2967  852453339132571648  2017-04-13 09:28:08          0         3      False
#
#                    source                                               text
# 2963  Twitter for Android  RT @Edourdoo: The Open Society Foundations say...
# 2964  Twitter for Android  RT @Edourdoo: In 2014, Hungary targeted orgs t...
# 2965  Twitter for Android  RT @Edourdoo: Orban says CEU is operating at a...
# 2966  Twitter for Android  RT @NAR: Tokyo on yen's climb: 'no comment' ht...
# 2967  Twitter for Android  RT @NAR: Japan Atomic Power looks to operate r...

# %%
bot_tweets.T
# Out:
#                                                          0     \
# id                                         858919901842604033
# created_at                                2017-05-01 05:43:57
# favorites                                                   0
# retweets                                                    5
# retweeted                                               False
# source                                    Twitter for Android
# text        RT @saxobank: Squawk: France election update: ...
#
#                                                          1     \
# id                                         858158868853125125
# created_at                                2017-04-29 03:19:52
# favorites                                                   0
# retweets                                                   38
# retweeted                                               False
# source                                    Twitter for Android
# ...

# %%
bot_tweets.columns
# Out:
# Index(['id', 'created_at', 'favorites', 'retweets', 'retweeted', 'source',
#        'text'],
#       dtype='object')

# %%
bot_tweets.dtypes
# Out:
# id             int64
# created_at    object
# favorites      int64
# retweets       int64
# retweeted       bool
# source        object
# text          object
# dtype: object

# %%
print(len(bot_tweets))
# Out:
# 2968

# %%
print(len(bot_tweets.columns))
# Out:
# 7

# %%
all_titles = bot_tweets["text"]

# %%
bot_tweets["text"]
# Out:
# 0       RT @saxobank: Squawk: France election update: ...
# 1       RT @XHNews: #BeltandRoadInitiative facilitates...
# 2       RT @XHNews: White House says U.S. President @r...
# 3       RT @XHNews: Indonesia lifts #tsunami warning a...
# 4       RT @XHNews: Once "world's heaviest woman" flow...
#                               ...
# 2963    RT @Edourdoo: The Open Society Foundations say...
# 2964    RT @Edourdoo: In 2014, Hungary targeted orgs t...
# 2965    RT @Edourdoo: Orban says CEU is operating at a...
# 2966    RT @NAR: Tokyo on yen's climb: 'no comment' ht...
# 2967    RT @NAR: Japan Atomic Power looks to operate r...
# Name: text, Length: 2968, dtype: object

# %%
column_names = ['id', 'text', 'created_at']
bot_tweets[column_names]
# Out:
#                       id                                               text  \
# 0     858919901842604033  RT @saxobank: Squawk: France election update: ...
# 1     858158868853125125  RT @XHNews: #BeltandRoadInitiative facilitates...
# 2     858158855364259840  RT @XHNews: White House says U.S. President @r...
# 3     858158855355858944  RT @XHNews: Indonesia lifts #tsunami warning a...
# 4     858158841250418688  RT @XHNews: Once "world's heaviest woman" flow...
# ...                  ...                                                ...
# 2963  852453668574162944  RT @Edourdoo: The Open Society Foundations say...
# 2964  852453630993195008  RT @Edourdoo: In 2014, Hungary targeted orgs t...
# 2965  852453450822680576  RT @Edourdoo: Orban says CEU is operating at a...
# 2966  852453362431905792  RT @NAR: Tokyo on yen's climb: 'no comment' ht...
# 2967  852453339132571648  RT @NAR: Japan Atomic Power looks to operate r...
#
#                created_at
# 0     2017-05-01 05:43:57
# ...

# %%
bot_tweets.iloc[4]
# Out:
# id                                           858158841250418688
# created_at                                  2017-04-29 03:19:46
# favorites                                                     0
# retweets                                                     49
# retweeted                                                 False
# source                                      Twitter for Android
# text          RT @XHNews: Once "world's heaviest woman" flow...
# Name: 4, dtype: object

# %%
bot_tweets["text"].iloc[4]
# Out:
# 'RT @XHNews: Once "world\'s heaviest woman" flown to UAE for further weight loss treatment after row with Indian doctor https://t.co/DYMAMtI4…'
